# %% [markdown]
# <a href="https://colab.research.google.com/github/mahek27200622/aiml/blob/main/poccie1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
iris = pd.read_csv('/content/iris.csv',names=['sepal_length','sepal_width','petal_length','petal_width','class'])
iris.info()
iris.head()
iris.tail()
iris.describe()
import matplotlib.pyplot as plt
plt.figure(figsize=(10,9))
x=iris['petal_length']
y=iris['petal_width']
plt.scatter(x,y)
plt.title("scatter plot petal length vs width")
plt.xlabel("petal_length")
plt.ylabel("petal_width")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, Id to 150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  151 non-null    object
#  1   sepal_width   151 non-null    object
#  2   petal_length  151 non-null    object
#  3   petal_width   151 non-null    object
#  4   class         151 non-null    object
# dtypes: object(5)
# memory usage: 7.1+ KB
# Text(0, 0.5, 'petal_width')
